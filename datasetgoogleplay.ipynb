# %%
# !pip install -qq google-play-scraper

# %%
import json
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter
from google_play_scraper import Sort, reviews, app
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)

# %%
app_packages = [
  'com.netflix.mediaclient',
  'com.spotify.music'

]

# %%
app_infos = []
for ap in tqdm(app_packages):
  info = app(ap, lang='pt-br', country='br')
  del info['comments']
  app_infos.append(info)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  5.88it/s]

# %%
def print_json(json_object):
  json_str = json.dumps(
    json_object,
    indent=2,
    sort_keys=True,
    default=str
  )
  print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
print_json(app_infos[0])
# Out:
# {
#   "adSupported": false,
#   "appId": "com.netflix.mediaclient",
#   "categories": [
#     {
#       "id": "ENTERTAINMENT",
#       "name": "Entretenimento"
#     }
#   ],
#   "containsAds": false,
#   "contentRating": "Classifica\u00e7\u00e3o 16 anos",
#   "contentRatingDescription": "Viol\u00eancia, Conte\u00fado Sexual, Drogas",
#   "currency": "BRL",
#   "description": "Se voc\u00ea quer assistir \u00e0s s\u00e9ries e filmes mais comentados do momento e ainda n\u00e3o \u00e9 assinante, inscreva-se e comece a usar o servi\u00e7o Netflix.\r\n\r\nA Netflix oferece conte\u00fado premiado de s\u00e9ries, filmes, document\u00e1rios e especiais de com\u00e9dia.\r\n\r\nComo funciona a Netflix? \r\n\r\n\u2022 Lan\u00e7amos s\u00e9ries e filmes o tempo todo. Voc\u00ea pode navegar por nossa sele\u00e7\u00e3o de t\u00edtulos novos e assistir aos seus favoritos diretamente no celular ou em um dos diversos aparelhos compat\u00edveis.\r\n\u2022 Classifique as s\u00e9ries de TV e os filmes de que mais gosta e indique suas prefer\u00eancias para que a Netflix possa sugerir os t\u00edtulos mais indicados para voc\u00ea.\r\n\u2022 As crian\u00e7as podem assistir a s\u00e9ries e filmes dentro de um espa\u00e7o seguro, com entretenimento para toda a fam\u00edlia.\r\n\u2022 Assista aos trailers de suas s\u00e9ries e filmes favoritos e fique sabendo quando novos epis\u00f3dios e lan\u00e7amentos estiverem dispon\u00edveis. \r\n\r\nPara conhecer todos os Termos e condi\u00e7\u00f5es, acesse http://www.netflix.com/termsofuse\r\nPara a Declara\u00e7\u00e3o de Privacidade, acesse http://www.netflix.com/privacy",
#   "descriptionHTML": "Se voc\u00ea quer assistir \u00e0s s\u00e9ries e filmes mais comentados do momento e ainda n\u00e3o \u00e9 assinante, inscreva-se e comece a usar o servi\u00e7o Netflix.<br><br>A Netflix oferece conte\u00fado premiado de s\u00e9ries, filmes, document\u00e1rios e especiais de com\u00e9dia.<br><br>Como funciona a Netflix? <br><br>\u2022 Lan\u00e7amos s\u00e9ries e filmes o tempo todo. Voc\u00ea pode navegar por nossa sele\u00e7\u00e3o de t\u00edtulos novos e assistir aos seus favoritos diretamente no celular ou em um dos diversos aparelhos compat\u00edveis.<br>\u2022 Classifique as s\u00e9ries de TV e os filmes de que mais gosta e indique suas prefer\u00eancias para que a Netflix possa sugerir os t\u00edtulos mais indicados para voc\u00ea.<br>\u2022 As crian\u00e7as podem assistir a s\u00e9ries e filmes dentro de um espa\u00e7o seguro, com entretenimento para toda a fam\u00edlia.<br>\u2022 Assista aos trailers de suas s\u00e9ries e filmes favoritos e fique sabendo quando novos epis\u00f3dios e lan\u00e7amentos estiverem dispon\u00edveis. <br><br>Para conhecer todos os Termos e condi\u00e7\u00f5es, acesse http://www.netflix.com/termsofuse<br>Para a Declara\u00e7\u00e3o de Privacidade, acesse http://www.netflix.com/privacy",
#   "developer": "Netflix, Inc.",
#   "developerAddress": "100 Winchester Circle\nLos Gatos, CA 95032-1815\nUSA",
#   "developerEmail": "playstore@netflix.com",
#   "developerId": "Netflix,+Inc.",
#   "developerWebsite": "http://www.netflix.com",
#   "free": true,
#   "genre": "Entretenimento",
#   "genreId": "ENTERTAINMENT",
#   "headerImage": "https://play-lh.googleusercontent.com/0rgPYj0GwZ6txpYZrzoMdhwzqg7vY6C9B-Ol7jlaz-Ox2rgpD4Tr82ZgDqkirrEohbGm",
#   "histogram": [
#     1834944,
#     441174,
#     683576,
#     1211659,
#     10354067
#   ],
#   "icon": "https://play-lh.googleusercontent.com/TBRwjS_qfJCSj1m7zZB93FnpJM5fSpMA_wUlFDLxWAb45T9RmwBvQd5cWR5viJJOhkI",
#   "inAppProductPrice": null,
#   "installs": "1.000.000.000+",
#   "lastUpdatedOn": "16 de mai. de 2024",
#   "minInstalls": 1000000000,
#   "offersIAP": false,
#   "originalPrice": null,
#   "price": 0,
#   "privacyPolicy": "http://www.netflix.com/privacy",
#   "ratings": 14525432,
#   "realInstalls": 2611905755,
#   "released": "5 de mai. de 2011",
#   "reviews": 1097282,
#   "sale": false,
#   "saleText": null,
#   "saleTime": null,
#   "score": 4.2260385,
#   "screenshots": [
#     "https://play-lh.googleusercontent.com/aay4hUA_t-LscN-qcxZag4vX9b5ZjRaBIp2rqDf_uphMlo1MxVrqGgoCy2xzZQGoTzI",
#     "https://play-lh.googleusercontent.com/hm_R3OOiBUlrfmEDoXQtlhF372fzOvVR4DaZFdrYIzAZdBf9u2UkJ5gwK8FCdZcSXjou",
#     "https://play-lh.googleusercontent.com/Vq0NCTaP5Bj_nEt_vQ16ScIzyU9Z7iOjnxNd9q64ZPnWcrSqKMfsmsOX9xwn9k_AQSo",
#     "https://play-lh.googleusercontent.com/TrF6E9XJpVqiOQYljSeKs407otXIoC1yfJerxtZF6mArwOjAhXXgwgGm_Y51mvlwF1mh",
#     "https://play-lh.googleusercontent.com/fhCmI5R5qKWLWqZS5GorIToZJHz2j2UgYjuPzXfostUxYMDDzJjyqDScjhSMJooEKv8",
#     "https://play-lh.googleusercontent.com/A-9i9Vinc1kbAYokSiC5thY-zWC_b3hziX7_GlAR4LLPiVmil9AtNC8tfJkYXwuqWg",
#     "https://play-lh.googleusercontent.com/z4w8r-v2T34KlE3dBRgs6T3AuboaykscDXB9JqMXkOYx841Hv3GujF2tcKqo8rR9TQ",
#     "https://play-lh.googleusercontent.com/NF5mStsYWhEl1zC8pe1vIVokKK2VKZCeIlZNn3lErelJn8F42pvkfm3c9k7FOl-gYw",
#     "https://play-lh.googleusercontent.com/jBgLUQ4P8moASYaF_a-dmbNxCq1nf1mPbwZeYDFvgwUIAOulsKfvjUtfxonAjke0CQ",
#     "https://play-lh.googleusercontent.com/FopZBu85hlXg4Mb03m7ijUmySUlWtAkYaZIBJyOqQ3tUOdz9J8hI89grN7qw_SfUmg",
#     "https://play-lh.googleusercontent.com/1PtGuCq2iFQaPdMAVaHVhBNgaEqlj1gr8K426vLmsZe94xSrx_6IJarH_9nbQK5S20ni",
#     "https://play-lh.googleusercontent.com/gyFMDGqOnhYh7bSt-yBF_kioYD0bIYMcE20RsSC7Z7vait3uXzSLDS6ma_sekjSLq-Y",
#     "https://play-lh.googleusercontent.com/pth0CNZmcgpGgzxC7SnHp13yNiP9qcf09zTmYu8gnFWOj-UZzGjAjK0ZwveZR6UG1Es",
#     "https://play-lh.googleusercontent.com/crHaw0jwk-mnGHP-Oi5AFl6OW3W9oihknMC1ou_kmdsXHb7y-tjjESOhTZ3En7vrQkNb",
#     "https://play-lh.googleusercontent.com/ZtDnzc_SLblRjkfJdX4LzP9OWPC2LrxH2QGFHvmBiAHHiTulg8wupAcQUpsPIP4vMg",
#     "https://play-lh.googleusercontent.com/92sBEn1pk9xWZHHSN5K7gh3qFJWYL24jHo9--kv6Rx4eSIb5fxVCZhWyLN6K-grdThw",
#     "https://play-lh.googleusercontent.com/fJY3fWBbh-TWd5dEOOPvY2A7lENsdX8vL7rXw9waDYnshjj6p7a0e__dOKFd39fh1jo"
#   ],
#   "summary": "A Netflix \u00e9 l\u00edder mundial em servi\u00e7o de assinatura de filmes e s\u00e9ries de TV.",
#   "title": "Netflix",
#   "updated": 1715899314,
#   "url": "https://play.google.com/store/apps/details?id=com.netflix.mediaclient&hl=pt-br&gl=br",
#   "version": null,
#   "video": null,
#   "videoImage": null
# }

# %%
app_infos_df = pd.DataFrame(app_infos)
app_infos_df.to_csv('apps.csv', index=None, header=True)

# %%
app_reviews = []
for ap in tqdm(app_packages):
  for score in list(range(1, 6)):
    for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
      rvs, _ = reviews(
        ap,
        lang='pt-br',
        country='br',
        sort=sort_order,
        count= 200 if score == 3 else 100,
        filter_score_with=score
      )
      for r in rvs:
        r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
        r['appId'] = ap
      app_reviews.extend(rvs)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.40s/it]

# %%
print_json(app_reviews[0])
# Out:
# {
#   "appId": "com.netflix.mediaclient",
#   "appVersion": "8.105.0 build 15 50626",
#   "at": "2024-03-12 22:37:56",
#   "content": "Sinceramente, estou decepcionado com a netflix. De algumas atualiza\u00e7\u00f5es para c\u00e1, tem estado simplesmente terr\u00edvel. Os pre\u00e7os est\u00e3o absurdamente caros, mas este n\u00e3o \u00e9 o fato em quest\u00e3o, desde 2023 n\u00e3o consigo mais assistir pela TV, pois compartilho conta e n\u00e3o posso assistir pois n\u00e3o estou na mesma resid\u00eancia do assinante, mas a quest\u00e3o \u00e9, eu ajudo a pagar, e gostaria muito de poder assistir, j\u00e1 que estou pagando. Nem em meu celular eu consigo assistir mais, netflix, melhore.",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "8.105.0 build 15 50626",
#   "reviewId": "a292142f-d91a-4589-bfa9-6b2214eb21ec",
#   "score": 1,
#   "sortOrder": "most_relevant",
#   "thumbsUpCount": 2578,
#   "userImage": "https://play-lh.googleusercontent.com/a-/ALV-UjWR-F4yW1a_6tCV7383sTPZPP_jb76_mph71-PobP5UGtQpChxU",
#   "userName": "Theo"
# }

# %%
len(app_reviews)
# Out:
# 2397

# %%
app_reviews_df.to_csv('reviews.csv', index=None, header=True, escapechar='\\')

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.to_csv('reviews.csv', index=None, header=True)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-26-35215ee147b8> in <cell line: 2>()
#       1 app_reviews_df = pd.DataFrame(app_reviews)
# ----> 2 app_reviews_df.to_csv('reviews.csv', index=None, header=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     257             )
#     258
# --> 259             self._save()
#     260
#     261     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     262         if self._need_to_save_header:
#     263             self._save_header()
# --> 264         self._save_body()
#     265
#     266     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     300             if start_i >= end_i:
#     301                 break
# --> 302             self._save_chunk(start_i, end_i)
#     303
#     304     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313         libwriters.write_csv_rows(
#     314             data,
#     315             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# Error: need to escape, but no escapechar set

# %%
print_json(app_reviews[0])
# Out:
# {
#   "appId": "com.netflix.mediaclient",
#   "appVersion": "8.105.0 build 15 50626",
#   "at": "2024-03-12 22:37:56",
#   "content": "Sinceramente, estou decepcionado com a netflix. De algumas atualiza\u00e7\u00f5es para c\u00e1, tem estado simplesmente terr\u00edvel. Os pre\u00e7os est\u00e3o absurdamente caros, mas este n\u00e3o \u00e9 o fato em quest\u00e3o, desde 2023 n\u00e3o consigo mais assistir pela TV, pois compartilho conta e n\u00e3o posso assistir pois n\u00e3o estou na mesma resid\u00eancia do assinante, mas a quest\u00e3o \u00e9, eu ajudo a pagar, e gostaria muito de poder assistir, j\u00e1 que estou pagando. Nem em meu celular eu consigo assistir mais, netflix, melhore.",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "8.105.0 build 15 50626",
#   "reviewId": "a292142f-d91a-4589-bfa9-6b2214eb21ec",
#   "score": 1,
#   "sortOrder": "most_relevant",
#   "thumbsUpCount": 2578,
#   "userImage": "https://play-lh.googleusercontent.com/a-/ALV-UjWR-F4yW1a_6tCV7383sTPZPP_jb76_mph71-PobP5UGtQpChxU",
#   "userName": "Theo"
# }

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.shape
# Out:
# (2397, 13)

# %%
app_reviews_df.head()
# Out:
#                                reviewId                     userName  \
# 0  a292142f-d91a-4589-bfa9-6b2214eb21ec                         Theo
# 1  23f37756-75b3-4a93-a760-b28550033bbb           Deivisson M. de Sá
# 2  8ab37816-3f72-4021-8b53-532da390dd34            Júlio-bole6 Sousa
# 3  dbe202e5-2f01-4313-b8ff-6b738d7066f7  Leonardo Pereira dos Santos
# 4  a48f3d60-bb2c-405d-96d3-14b6e9eaef42                Rayssa Arruda
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Sinceramente, estou decepcionado com a netflix...      1           2578
# 1  Não é mais a mesma. O sucesso subio a cabeça e...      1            271
# 2  Pra começo de conversa, a Netflix anda casa ve...      1           1386
# 3  Primeiro encheram de filmes malucos e sem nexo...      1            343
# 4  A Netflix está desapontando seus usuários. Pri...      1           1271
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0  8.105.0 build 15 50626 2024-03-12 22:37:56         None       NaT
# 1  8.105.0 build 15 50626 2024-03-26 02:18:48         None       NaT
# 2   8.112.1 build 6 50665 2024-04-25 19:44:55         None       NaT
# 3   8.109.0 build 7 50647 2024-04-04 00:37:13         None       NaT
# 4   8.109.0 build 7 50647 2024-04-08 20:38:29         None       NaT
#
#                appVersion      sortOrder                    appId
# 0  8.105.0 build 15 50626  most_relevant  com.netflix.mediaclient
# 1  8.105.0 build 15 50626  most_relevant  com.netflix.mediaclient
# 2   8.112.1 build 6 50665  most_relevant  com.netflix.mediaclient
# 3   8.109.0 build 7 50647  most_relevant  com.netflix.mediaclient
# 4   8.109.0 build 7 50647  most_relevant  com.netflix.mediaclient

# %%
app_reviews_df.tail()
# Out:
#                                   reviewId                 userName  \
# 2392  6c744ced-9409-4b73-a246-995f33274ee6  Yasmin Gabriel da silva
# 2393  278af25e-4e8f-4438-b0e6-17a109477a16           Com amor, Paty
# 2394  0739699b-dc62-407d-abba-622d5f7fbb5a           Denilson Padua
# 2395  254d9632-c431-44bd-8318-9d3485531657         Alessandro Couto
# 2396  78a31709-8148-4aca-b99a-8695f20fd41b              Katty Carol
#
#                                               userImage  \
# 2392  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2393  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2394  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2395  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2396  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 2392                                     Maravilhosoooo      5              0
# 2393  Só uso o Spotify, eu amo, faço minhas playlist...      5              0
# 2394  Me traz o que procuro com facilidade e me traz...      5              0
# 2395                                          Excelente      5              0
# 2396                                         Bom D Mais      5              0
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 2392           8.9.40.509 2024-05-18 15:17:06         None       NaT
# 2393           8.9.40.509 2024-05-18 15:13:50         None       NaT
# 2394           8.9.40.509 2024-05-18 15:10:11         None       NaT
# 2395           8.9.40.509 2024-05-18 15:05:22         None       NaT
# 2396           8.9.40.509 2024-05-18 14:59:49         None       NaT
#
#       appVersion sortOrder              appId
# 2392  8.9.40.509    newest  com.spotify.music
# 2393  8.9.40.509    newest  com.spotify.music
# 2394  8.9.40.509    newest  com.spotify.music
# 2395  8.9.40.509    newest  com.spotify.music
# 2396  8.9.40.509    newest  com.spotify.music

# %%
app_reviews_df.to_csv('reviews.csv', index=None, header=True)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-31-0b24a1101dd8> in <cell line: 1>()
# ----> 1 app_reviews_df.to_csv('reviews.csv', index=None, header=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     257             )
#     258
# --> 259             self._save()
#     260
#     261     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     262         if self._need_to_save_header:
#     263             self._save_header()
# --> 264         self._save_body()
#     265
#     266     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     300             if start_i >= end_i:
#     301                 break
# --> 302             self._save_chunk(start_i, end_i)
#     303
#     304     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313         libwriters.write_csv_rows(
#     314             data,
#     315             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# Error: need to escape, but no escapechar set

# %%
app_reviews_df.to_csv('reviews.csv', index=None, header=True, escapechar='\\')

# %%
app_reviews_df.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion     280
# at                         0
# replyContent            2396
# repliedAt               2396
# appVersion               280
# sortOrder                  0
# appId                      0
# dtype: int64

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2397 entries, 0 to 2396
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              2397 non-null   object
#  1   userName              2397 non-null   object
#  2   userImage             2397 non-null   object
#  3   content               2397 non-null   object
#  4   score                 2397 non-null   int64
#  5   thumbsUpCount         2397 non-null   int64
#  6   reviewCreatedVersion  2117 non-null   object
#  7   at                    2397 non-null   datetime64[ns]
#  8   replyContent          1 non-null      object
#  9   repliedAt             1 non-null      datetime64[ns]
#  10  appVersion            2117 non-null   object
#  11  sortOrder             2397 non-null   object
#  12  appId                 2397 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 243.6+ KB

# %%
app_reviews_df
# Out:
#                                   reviewId                     userName  \
# 0     a292142f-d91a-4589-bfa9-6b2214eb21ec                         Theo
# 1     23f37756-75b3-4a93-a760-b28550033bbb           Deivisson M. de Sá
# 2     8ab37816-3f72-4021-8b53-532da390dd34            Júlio-bole6 Sousa
# 3     dbe202e5-2f01-4313-b8ff-6b738d7066f7  Leonardo Pereira dos Santos
# 4     a48f3d60-bb2c-405d-96d3-14b6e9eaef42                Rayssa Arruda
# ...                                    ...                          ...
# 2392  6c744ced-9409-4b73-a246-995f33274ee6      Yasmin Gabriel da silva
# 2393  278af25e-4e8f-4438-b0e6-17a109477a16               Com amor, Paty
# 2394  0739699b-dc62-407d-abba-622d5f7fbb5a               Denilson Padua
# 2395  254d9632-c431-44bd-8318-9d3485531657             Alessandro Couto
# 2396  78a31709-8148-4aca-b99a-8695f20fd41b                  Katty Carol
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 2392  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2393  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2394  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2395  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2396  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0     Sinceramente, estou decepcionado com a netflix...      1           2578
# 1     Não é mais a mesma. O sucesso subio a cabeça e...      1            271
# 2     Pra começo de conversa, a Netflix anda casa ve...      1           1386
# 3     Primeiro encheram de filmes malucos e sem nexo...      1            343
# 4     A Netflix está desapontando seus usuários. Pri...      1           1271
# ...                                                 ...    ...            ...
# 2392                                     Maravilhosoooo      5              0
# 2393  Só uso o Spotify, eu amo, faço minhas playlist...      5              0
# 2394  Me traz o que procuro com facilidade e me traz...      5              0
# 2395                                          Excelente      5              0
# 2396                                         Bom D Mais      5              0
#
#         reviewCreatedVersion                  at replyContent repliedAt  \
# 0     8.105.0 build 15 50626 2024-03-12 22:37:56         None       NaT
# 1     8.105.0 build 15 50626 2024-03-26 02:18:48         None       NaT
# 2      8.112.1 build 6 50665 2024-04-25 19:44:55         None       NaT
# 3      8.109.0 build 7 50647 2024-04-04 00:37:13         None       NaT
# 4      8.109.0 build 7 50647 2024-04-08 20:38:29         None       NaT
# ...                      ...                 ...          ...       ...
# 2392              8.9.40.509 2024-05-18 15:17:06         None       NaT
# 2393              8.9.40.509 2024-05-18 15:13:50         None       NaT
# 2394              8.9.40.509 2024-05-18 15:10:11         None       NaT
# 2395              8.9.40.509 2024-05-18 15:05:22         None       NaT
# 2396              8.9.40.509 2024-05-18 14:59:49         None       NaT
#
#                   appVersion      sortOrder                    appId
# 0     8.105.0 build 15 50626  most_relevant  com.netflix.mediaclient
# 1     8.105.0 build 15 50626  most_relevant  com.netflix.mediaclient
# 2      8.112.1 build 6 50665  most_relevant  com.netflix.mediaclient
# 3      8.109.0 build 7 50647  most_relevant  com.netflix.mediaclient
# 4      8.109.0 build 7 50647  most_relevant  com.netflix.mediaclient
# ...                      ...            ...                      ...
# 2392              8.9.40.509         newest        com.spotify.music
# 2393              8.9.40.509         newest        com.spotify.music
# 2394              8.9.40.509         newest        com.spotify.music
# 2395              8.9.40.509         newest        com.spotify.music
# 2396              8.9.40.509         newest        com.spotify.music
#
# [2397 rows x 13 columns]

# %%
data_corte = pd.Timestamp('2022-04-04')

# %%
reviews_filtrado = app_reviews_df[app_reviews_df['at'] >= data_corte]

# %%
reviews_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2057 entries, 0 to 2396
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              2057 non-null   object
#  1   userName              2057 non-null   object
#  2   userImage             2057 non-null   object
#  3   content               2057 non-null   object
#  4   score                 2057 non-null   int64
#  5   thumbsUpCount         2057 non-null   int64
#  6   reviewCreatedVersion  1819 non-null   object
#  7   at                    2057 non-null   datetime64[ns]
#  8   replyContent          1 non-null      object
#  9   repliedAt             1 non-null      datetime64[ns]
#  10  appVersion            1819 non-null   object
#  11  sortOrder             2057 non-null   object
#  12  appId                 2057 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 225.0+ KB

# %%
# Filtrando as avaliações para o Netflix
netflix_reviews = reviews_filtrado[reviews_filtrado['appId'] == 'com.netflix.mediaclient']

# Filtrando as avaliações para o Spotify
spotify_reviews = reviews_filtrado[reviews_filtrado['appId'] == 'com.spotify.music']

# %%
netflix_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 859 entries, 0 to 1198
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              859 non-null    object
#  1   userName              859 non-null    object
#  2   userImage             859 non-null    object
#  3   content               859 non-null    object
#  4   score                 859 non-null    int64
#  5   thumbsUpCount         859 non-null    int64
#  6   reviewCreatedVersion  714 non-null    object
#  7   at                    859 non-null    datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      datetime64[ns]
#  10  appVersion            714 non-null    object
#  11  sortOrder             859 non-null    object
#  12  appId                 859 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 94.0+ KB

# %%
spotify_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1198 entries, 1199 to 2396
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1198 non-null   object
#  1   userName              1198 non-null   object
#  2   userImage             1198 non-null   object
#  3   content               1198 non-null   object
#  4   score                 1198 non-null   int64
#  5   thumbsUpCount         1198 non-null   int64
#  6   reviewCreatedVersion  1105 non-null   object
#  7   at                    1198 non-null   datetime64[ns]
#  8   replyContent          1 non-null      object
#  9   repliedAt             1 non-null      datetime64[ns]
#  10  appVersion            1105 non-null   object
#  11  sortOrder             1198 non-null   object
#  12  appId                 1198 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 131.0+ KB

# %%
# !pip install --upgrade nbformat nbconvert
# Out:
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (5.10.4)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (6.5.4)
# Collecting nbconvert
#   Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat) (4.19.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert)
#   Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert) (24.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert) (1.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from nbclient>=0.5.0->nbconvert) (6.1.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert) (2.5)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (24.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.8.2)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.3.3)
# Installing collected packages: mistune, nbconvert
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
# Successfully installed mistune-3.0.2 nbconvert-7.16.4
